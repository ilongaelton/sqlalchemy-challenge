# %%
# pip install sqlalchemy pandas matplotlib

# %%
from sqlalchemy import create_engine

# Create an engine that connects to the SQLite database
engine = create_engine('sqlite:///hawaii.sqlite')

# %%
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import sessionmaker

# Reflect the database schema to create ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)

# Save references to the tables as classes
Station = Base.classes.station
Measurement = Base.classes.measurement
# Out:
# C:\Users\owner\AppData\Local\Temp\ipykernel_22000\1829734942.py:6: SADeprecationWarning: The AutomapBase.prepare.reflect parameter is deprecated and will be removed in a future release.  Reflection is enabled when AutomapBase.prepare.autoload_with is passed.
#   Base.prepare(engine, reflect=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\_collections.py:215, in Properties.__getattr__(self, key)
#     214 try:
# --> 215     return self._data[key]
#     216 except KeyError:
#
# KeyError: 'station'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       6 Base.prepare(engine, reflect=True)
#       8 # Save references to the tables as classes
# ----> 9 Station = Base.classes.station
#      10 Measurement = Base.classes.measurement
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\_collections.py:217, in Properties.__getattr__(self, key)
#     215     return self._data[key]
#     216 except KeyError:
# --> 217     raise AttributeError(key)
#
# AttributeError: station

# %%
# Create a session to interact with the database
Session = sessionmaker(bind=engine)
session = Session()

# %%
# Close the session at the end
session.close()
